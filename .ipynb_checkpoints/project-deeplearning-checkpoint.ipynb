# %%
# -----------------------------------------------------------
# Handwritten Digit Recognition using Deep Learning
# Dataset: MNIST
# -----------------------------------------------------------

# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# Import dataset and deep learning tools
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# -----------------------------------------------------------
# STEP 1: Load Dataset
# -----------------------------------------------------------

# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("Training Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)

# -----------------------------------------------------------
# STEP 2: Data Preprocessing
# -----------------------------------------------------------

# Normalize pixel values (0–255 → 0–1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# Convert labels to categorical format
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# -----------------------------------------------------------
# STEP 3: Build Deep Learning Model
# -----------------------------------------------------------

model = Sequential()

# Convert 28x28 image to 784 vector
model.add(Flatten(input_shape=(28, 28)))

# Hidden layers
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))

# Output layer (10 digits)
model.add(Dense(10, activation='softmax'))

# Show model architecture
model.summary()

# -----------------------------------------------------------
# STEP 4: Compile Model
# -----------------------------------------------------------

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# -----------------------------------------------------------
# STEP 5: Train Model
# -----------------------------------------------------------

history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)

# -----------------------------------------------------------
# STEP 6: Test Model
# -----------------------------------------------------------

test_loss, test_accuracy = model.evaluate(X_test, y_test)

print("\nTest Accuracy:", test_accuracy)

# -----------------------------------------------------------
# STEP 7: Make Predictions
# -----------------------------------------------------------

predictions = model.predict(X_test)

# Show first test image
plt.imshow(X_test[0], cmap='gray')

# Show predicted digit
plt.title("Predicted Digit: " + str(np.argmax(predictions[0])))

plt.show()

# -----------------------------------------------------------
# STEP 8: Plot Accuracy Graph
# -----------------------------------------------------------

plt.figure()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.legend(["Training Accuracy", "Validation Accuracy"])

plt.show()

# -----------------------------------------------------------
# STEP 9: Plot Loss Graph
# -----------------------------------------------------------

plt.figure()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(["Training Loss", "Validation Loss"])

plt.show()
# Out:
# Training Data Shape: (60000, 28, 28)
# Testing Data Shape: (10000, 28, 28)
# H:\Anaconda\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9204 - loss: 0.2701 - val_accuracy: 0.9604 - val_loss: 0.1348
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9670 - loss: 0.1126 - val_accuracy: 0.9678 - val_loss: 0.1073
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9759 - loss: 0.0780 - val_accuracy: 0.9739 - val_loss: 0.0901
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9821 - loss: 0.0567 - val_accuracy: 0.9702 - val_loss: 0.1066
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9855 - loss: 0.0453 - val_accuracy: 0.9726 - val_loss: 0.0967
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9883 - loss: 0.0364 - val_accuracy: 0.9756 - val_loss: 0.0972
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9903 - loss: 0.0289 - val_accuracy: 0.9772 - val_loss: 0.0935
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9918 - loss: 0.0250 - val_accuracy: 0.9771 - val_loss: 0.0839
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9932 - loss: 0.0205 - val_accuracy: 0.9764 - val_loss: 0.0949
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9933 - loss: 0.0204 - val_accuracy: 0.9696 - val_loss: 0.1318
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9737 - loss: 0.1143
#
# Test Accuracy: 0.9736999869346619
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
